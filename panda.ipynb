# %%
import random

# %%
a1=[]
a2=[]
a3=[]
a4=[]
a5=[]

# %%
for _ in range(1000):
  a1.append (random.randint(0,100))
  a2.append (random.randint(50,70))
  a3.append (random.randint(10,20))
  a4.append (random.randint(5,10))
  a5.append (random.randint(20,80))

# %%
df = {
    'grade' : a1,
    'weight' :a2,
    'friends' : a3,
    'cousins'  : a4,
    'project' :a5

    }

# %%
import pandas as pd

# %%
df1 = pd.DataFrame(df)

# %%
df1
# Out:
#      grade  weight  friends  cousins  project
# 0       44      55       13        8       26
# 1        6      69       11       10       63
# 2       42      65       20        9       68
# 3       78      61       14       10       29
# 4       58      54       10        6       25
# ..     ...     ...      ...      ...      ...
# 995     46      67       16        8       53
# 996     90      69       10        7       23
# 997     98      58       12        9       80
# 998      8      67       11        5       26
# 999      2      55       10        5       21
#
# [1000 rows x 5 columns]

# %%
df1.describe()
# Out:
#              grade       weight      friends      cousins     project
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     51.361000    59.661000    14.983000     7.437000    49.36000
# std      29.940526     6.180961     3.123214     1.708493    17.65503
# min       0.000000    50.000000    10.000000     5.000000    20.00000
# 25%      25.000000    54.000000    12.000000     6.000000    34.00000
# 50%      53.500000    59.000000    15.000000     7.000000    49.00000
# 75%      78.000000    65.000000    18.000000     9.000000    64.00000
# max     100.000000    70.000000    20.000000    10.000000    80.00000

# %%
df1['grade'].count()
# Out:
# 1000

# %%
friend15 = df1['friends']>15

# %%
df1[friend15]
# Out:
#      grade  weight  friends  cousins  project
# 2       42      65       20        9       68
# 5       31      53       19        5       76
# 10      58      60       18        8       34
# 17      64      67       20        8       39
# 18       3      63       18        8       31
# ..     ...     ...      ...      ...      ...
# 987      4      52       18        9       53
# 988     26      70       19        5       53
# 989     59      50       18        6       57
# 991     47      53       20        6       64
# 995     46      67       16        8       53
#
# [458 rows x 5 columns]

# %%
grade50 = df1['grade']>50

# %%
df1[grade50]
# Out:
#      grade  weight  friends  cousins  project
# 3       78      61       14       10       29
# 4       58      54       10        6       25
# 6       99      50       12        8       43
# 7       88      51       11        9       63
# 8       99      51       15        8       37
# ..     ...     ...      ...      ...      ...
# 984     55      58       17        5       32
# 989     59      50       18        6       57
# 990     92      52       14        7       42
# 996     90      69       10        7       23
# 997     98      58       12        9       80
#
# [536 rows x 5 columns]

# %%
df1[friend15 & grade50]
# Out:
#      grade  weight  friends  cousins  project
# 10      58      60       18        8       34
# 17      64      67       20        8       39
# 24      95      55       18        9       65
# 27      57      51       18        9       40
# 32      82      69       19        5       73
# ..     ...     ...      ...      ...      ...
# 976     92      51       19        8       28
# 979     72      61       20        5       37
# 981     62      54       20        9       62
# 984     55      58       17        5       32
# 989     59      50       18        6       57
#
# [254 rows x 5 columns]

# %%
df1[friend15 & grade50]['friends']
# Out:
# 10     18
# 17     20
# 24     18
# 27     18
# 32     19
#        ..
# 976    19
# 979    20
# 981    20
# 984    17
# 989    18
# Name: friends, Length: 254, dtype: int64

# %%
from matplotlib import pyplot as plt

# %%
df1[friend15 & grade50].plot()
# Out:
# <Axes: >

# %%
# %matplotlib inline

# %%
df1[friend15 & grade50].plot(x='grade',y='project',kind='bar',title='graph')
# Out:
# <Axes: title={'center': 'graph'}, xlabel='grade'>

# %%
fdf =df1[friend15 & grade50]

# %%
fdf
# Out:
#      grade  weight  friends  cousins  project
# 10      58      60       18        8       34
# 17      64      67       20        8       39
# 24      95      55       18        9       65
# 27      57      51       18        9       40
# 32      82      69       19        5       73
# ..     ...     ...      ...      ...      ...
# 976     92      51       19        8       28
# 979     72      61       20        5       37
# 981     62      54       20        9       62
# 984     55      58       17        5       32
# 989     59      50       18        6       57
#
# [254 rows x 5 columns]
